# %%
import pandas as pd

# %%
import numpy as np

# %%
# %matplotlib inline #pour incruster les graphiques dans le book
# Out:
# UsageError: unrecognized arguments: #pour incruster les graphiques dans le book

# %% [markdown]
# ## Séries

# %%
donnees= np.random.randint(1,7, size=(30))
donnees
# Out:
# array([5, 6, 5, 2, 4, 5, 4, 5, 3, 3, 1, 3, 4, 1, 3, 1, 1, 3, 6, 1, 4, 1,
#        6, 3, 3, 1, 6, 2, 6, 4])

# %%
dir(donnees)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
# ...

# %%
len(dir(donnees))
# Out:
# 161

# %%
lancers = pd.Series(donnees)
print(type(donnees))
print(type(lancers))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>

# %%
len(dir(lancers))
# Out:
# 450

# %%
lancers.values
# Out:
# array([5, 6, 5, 2, 4, 5, 4, 5, 3, 3, 1, 3, 4, 1, 3, 1, 1, 3, 6, 1, 4, 1,
#        6, 3, 3, 1, 6, 2, 6, 4])

# %%
lancers.value_counts()
# Out:
# 3    7
# 1    7
# 6    5
# 4    5
# 5    4
# 2    2
# dtype: int64

# %%
lancers.plot()

# %%
lancers.plot.hist()

# %%
lancers.plot.bar()

# %%
lancers.apply(lambda x: "Face" if x % )

# %%
lancers.mean()
# Out:
# 3.4

# %%
lancers.mode()
# Out:
# 0    1
# 1    3
# dtype: int32

# %%
lancers.dtype
# Out:
# dtype('int32')

# %% [markdown]
# ## DataFrame

# %%
lancers = pd.DataFrame({
    "des1" : np.random.randint(1, 7, size=(30)),
    "des2" : np.random.randint(1, 7, size=(30)),
    "des3" : np.random.randint(1, 7, size=(30)),
    "des4" : np.random.randint(1, 7, size=(30)),
    }
)
lancers.head()
# Out:
#    des1  des2  des3  des4
# 0     3     3     4     6
# 1     2     5     1     1
# 2     6     2     3     4
# 3     3     2     2     6
# 4     3     6     5     4

# %%
lancers.columns
# Out:
# Index(['des1', 'des2', 'des3', 'des4'], dtype='object')

# %%
lancers.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
type(lancers.des1) #Pour accéder aux colonnes
# Out:
# pandas.core.series.Series

# %%
lancers["des1"] == lancers.des1 #exécution d'un test d'égalité binaire
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# Name: des1, dtype: bool

# %%
lancers["des1"] is lancers.des1
# Out:
# True

# %%
id(lancers.des1) #L'adresse mémoire où est stocké la première colonne
# Out:
# 776585848144

# %%
id(lancers["des1"])
# Out:
# 776585848144

# %%
lancers["Somme"] = lancers.des1 + lancers.des2 + lancers.des3 + lancers.des4

# %%
lancers.tail()
# Out:
#     des1  des2  des3  des4  Somme
# 25     5     6     6     1     18
# 26     1     6     6     6     19
# 27     2     6     4     6     18
# 28     1     6     4     3     14
# 29     2     2     5     4     13

# %%
lancers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
# des1     30 non-null int32
# des2     30 non-null int32
# des3     30 non-null int32
# des4     30 non-null int32
# Somme    30 non-null int32
# dtypes: int32(5)
# memory usage: 680.0 bytes

# %%
lancers[["des1", "des2", "des3", "des4"]]
# Out:
#     des1  des2  des3  des4
# 0      3     3     4     6
# 1      2     5     1     1
# 2      6     2     3     4
# 3      3     2     2     6
# 4      3     6     5     4
# 5      1     1     2     2
# 6      3     2     5     2
# 7      5     3     3     5
# 8      6     5     4     3
# 9      4     5     3     5
# 10     5     2     5     5
# 11     4     3     3     2
# 12     4     1     3     6
# 13     2     2     6     6
# 14     1     6     4     3
# 15     1     1     2     3
# 16     5     4     3     6
# 17     2     3     5     1
# 18     1     5     4     4
# 19     6     4     3     5
# 20     6     5     4     1
# 21     3     5     4     5
# 22     6     6     5     2
# 23     4     2     4     4
# 24     4     4     4     4
# 25     5     6     6     1
# 26     1     6     6     6
# 27     2     6     4     6
# 28     1     6     4     3
# 29     2     2     5     4

# %%
lancers.drop("Somme", axis=1) #Drop permet de se débasser de lignes ou de colonnes
# Out:
#     des1  des2  des3  des4
# 0      3     3     4     6
# 1      2     5     1     1
# 2      6     2     3     4
# 3      3     2     2     6
# 4      3     6     5     4
# 5      1     1     2     2
# 6      3     2     5     2
# 7      5     3     3     5
# 8      6     5     4     3
# 9      4     5     3     5
# 10     5     2     5     5
# 11     4     3     3     2
# 12     4     1     3     6
# 13     2     2     6     6
# 14     1     6     4     3
# 15     1     1     2     3
# 16     5     4     3     6
# 17     2     3     5     1
# 18     1     5     4     4
# 19     6     4     3     5
# 20     6     5     4     1
# 21     3     5     4     5
# 22     6     6     5     2
# 23     4     2     4     4
# 24     4     4     4     4
# 25     5     6     6     1
# 26     1     6     6     6
# 27     2     6     4     6
# 28     1     6     4     3
# 29     2     2     5     4

# %%
lancers.apply?

# %%
lancers.apply(lambda x: len(set(x)) < 4, axis=1) #Ici on détecte les lignes où il y a deux
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24     True
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# dtype: bool

# %%
lancers["egalite"]= (lancers.drop("Somme", axis=1).apply(lambda x: len(set(x)) < 4, axis=1))

# %%
lancers
# Out:
#     des1  des2  des3  des4  Somme  egalite
# 0      3     3     4     6     16     True
# 1      2     5     1     1      9     True
# 2      6     2     3     4     15    False
# 3      3     2     2     6     13     True
# 4      3     6     5     4     18    False
# 5      1     1     2     2      6     True
# 6      3     2     5     2     12     True
# 7      5     3     3     5     16     True
# 8      6     5     4     3     18    False
# 9      4     5     3     5     17     True
# 10     5     2     5     5     17     True
# 11     4     3     3     2     12     True
# 12     4     1     3     6     14    False
# 13     2     2     6     6     16     True
# 14     1     6     4     3     14    False
# 15     1     1     2     3      7     True
# 16     5     4     3     6     18    False
# 17     2     3     5     1     11    False
# 18     1     5     4     4     14     True
# 19     6     4     3     5     18    False
# 20     6     5     4     1     16    False
# ...

# %%
lancers["egalite"].value_counts()
# Out:
# True     20
# False    10
# Name: egalite, dtype: int64

# %%
lancers.loc[1, "Somme"] # .loc[] pour selection les lignes
# Out:
# 9

# %%
lancers.loc[1:5, "Somme"]
# Out:
# 1     9
# 2    15
# 3    13
# 4    18
# 5     6
# Name: Somme, dtype: int32

# %%
lancers.iloc[1, 4]
# Out:
# 9

# %%
lancers.iloc[0: 11, 0: 4] #.iloc[] permet aussi d'extraire les lignes
# Out:
#     des1  des2  des3  des4
# 0      3     3     4     6
# 1      2     5     1     1
# 2      6     2     3     4
# 3      3     2     2     6
# 4      3     6     5     4
# 5      1     1     2     2
# 6      3     2     5     2
# 7      5     3     3     5
# 8      6     5     4     3
# 9      4     5     3     5
# 10     5     2     5     5

# %%
lancers["Somme"] > 15
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19     True
# 20     True
# 21     True
# 22     True
# 23    False
# 24     True
# 25     True
# 26     True
# 27     True
# 28    False
# 29    False
# Name: Somme, dtype: bool

# %%
grande_somme = lancers["Somme"] > 15

# %%
lancers.loc[grande_somme]
# Out:
#     des1  des2  des3  des4  Somme  egalite
# 0      3     3     4     6     16     True
# 4      3     6     5     4     18    False
# 7      5     3     3     5     16     True
# 8      6     5     4     3     18    False
# 9      4     5     3     5     17     True
# 10     5     2     5     5     17     True
# 13     2     2     6     6     16     True
# 16     5     4     3     6     18    False
# 19     6     4     3     5     18    False
# 20     6     5     4     1     16    False
# 21     3     5     4     5     17     True
# 22     6     6     5     2     19     True
# 24     4     4     4     4     16     True
# 25     5     6     6     1     18     True
# 26     1     6     6     6     19     True
# 27     2     6     4     6     18     True

# %%
lancers.query("Somme > 15")
# Out:
#     des1  des2  des3  des4  Somme  egalite
# 0      3     3     4     6     16     True
# 4      3     6     5     4     18    False
# 7      5     3     3     5     16     True
# 8      6     5     4     3     18    False
# 9      4     5     3     5     17     True
# 10     5     2     5     5     17     True
# 13     2     2     6     6     16     True
# 16     5     4     3     6     18    False
# 19     6     4     3     5     18    False
# 20     6     5     4     1     16    False
# 21     3     5     4     5     17     True
# 22     6     6     5     2     19     True
# 24     4     4     4     4     16     True
# 25     5     6     6     1     18     True
# 26     1     6     6     6     19     True
# 27     2     6     4     6     18     True

# %%
lancers.head()
# Out:
#    des1  des2  des3  des4  Somme  egalite
# 0     3     3     4     6     16     True
# 1     2     5     1     1      9     True
# 2     6     2     3     4     15    False
# 3     3     2     2     6     13     True
# 4     3     6     5     4     18    False

# %%
lancers.groupby("Somme").count()
# Out:
#        des1  des2  des3  des4  egalite
# Somme
# 6         1     1     1     1        1
# 7         1     1     1     1        1
# 9         1     1     1     1        1
# 11        1     1     1     1        1
# 12        2     2     2     2        2
# 13        2     2     2     2        2
# 14        5     5     5     5        5
# 15        1     1     1     1        1
# 16        5     5     5     5        5
# 17        3     3     3     3        3
# 18        6     6     6     6        6
# 19        2     2     2     2        2

# %%
lancers.groupby("egalite").agg("mean") #on regroupe les résultats en les aggregeant.
# Out:
#          des1  des2  des3  des4  Somme
# egalite
# False    4.00  4.20   3.8  3.60  15.60
# True     3.05  3.55   3.9  3.95  14.45

# %%
lancers.plot.scatter("des1", "des2")

# %%
lancers.plot.bar()

# %%
lancers.plot.hexbin("des1", "des2")

# %%
lancers_bis = pd.DataFrame(np.random.randint(1, 7, size=(10, 5)))

# %%
lancers_bis.head()
# Out:
#    0  1  2  3  4
# 0  2  5  5  5  1
# 1  5  6  2  1  2
# 2  4  1  3  4  4
# 3  5  6  2  5  3
# 4  4  1  4  3  4

# %%
lancers_bis.columns = ["des1", "des2", "des3", "des4", "des5"]

# %%
lancers_bis.head()
# Out:
#    des1  des2  des3  des4  des5
# 0     2     5     5     5     1
# 1     5     6     2     1     2
# 2     4     1     3     4     4
# 3     5     6     2     5     3
# 4     4     1     4     3     4

# %%
for col in lancers_bis.columns:
    print(col)
# Out:
# des1
# des2
# des3
# des4
# des5
