# %%
import requests as rq

# %%
page = rq.get("https://fr.wikipedia.org/wiki/France")

# %%
type(page)
# Out:
# requests.models.Response

# %%
dir(page)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
print(page.url)
# Out:
# https://fr.wikipedia.org/wiki/France

# %%
page.status_code
# Out:
# 200

# %%
type(page.text)
# Out:
# str

# %%
len(page.text) #"Len" renvoie le nombre d'éléments dans un conteneur.
# Out:
# 1364484

# %%
lignes=page.text.splitlines() #"Splitlines découpe toutes les lignes en fichier text

# %%
for i, ligne in enumerate(lignes[:10]):
    print(i)
    print(ligne)
    print()
# Out:
# 0
# <!DOCTYPE html>
#
# 1
# <html class="client-nojs" lang="fr" dir="ltr">
#
# 2
# <head>
#
# 3
# <meta charset="UTF-8"/>
#
# 4
# <title>France — Wikipédia</title>
#
# 5
# ...

# %%
texte=page.text

# %%
type(texte)
# Out:
# str

# %%
dir(texte)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
indice=texte.find("France")
print(texte[indice: indice + 100])
# Out:
# France — Wikipédia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgCanonic

# %%
indice = 0
while indice != -1:
    indice = texte.find("France", indice + 1)
    print(indice)
    print(texte[indice: indice + 50])
    print()
# Out:
# 101
# France — Wikipédia</title>
# <script>document.docume
#
# 285
# France","wgTitle":"France","wgCurRevisionId":16284
#
# 304
# France","wgCurRevisionId":162845388,"wgRevisionId"
#
# 1619
# France/Articles liés","Portail:Europe/Articles lié
#
# 2286
# France"],"wgBreakFrames":!1,"wgPageContentLanguage
#
# 2742
# France","wgRelevantArticleId":1095,"wgRequestId":"
#
# 6628
# France"/>
# <link rel="apple-touch-icon" href="/stat
#
# 7119
# France"/>
# <link rel="dns-prefetch" href="//login.w
#
# 7420
# France rootpage-France skin-vector action-view">
# <
#
# 7436
# France skin-vector action-view">
# <div id="mw-page-
#
# 9457
# France</h1>
#
# 	<div id="bodyContent" class="mw-bod
#
# 11443
# France&#160;», voir <a href="/wiki/France_(homonym
#
# 11478
# France_(homonymie)" class="mw-disambig" title="Fra
#
# 11525
# France (homonymie)">France (homonymie)</a>. Pour u
#
# 11545
# France (homonymie)</a>. Pour une présentation géné
#
# 11700
# ...

# %%
def recherche(motif):
    indice = 0
    resultat = []
    while indice != -1:
        indice = texte.find("France", indice + 1)
        resultat.append((indice, texte[indice: indice + 50]))
    return resultat

# %%
len(recherche("France"))
# Out:
# 1575

# %% [markdown]
# # Exercice

# %% [markdown]
# Construire un script qui prenant le nom d'un pays renvoit le nombre de fois où le nom du pays apparait dans sa fiche wikipédia.

# %%
# %run occurences_pays.py
# Out:
# 1575

# %%
from occurences_pays import nb_occurences

# %%
nb_occurences("Allemagne")
# Out:
# 676

# %%
nb_occurences("France")
# Out:
# 1575

# %%
nb_occurences("Espagne")
# Out:
# 523

# %%
nb_occurences("Royaume-Uni")
# Out:
# 445

# %%
nb_occurences
# Out:
# <function occurences_pays.nb_occurences(nom_du_pays)>

# %% [markdown]
# # Expressions régulières

# %%
import re #Gestion des chaines de caractères

# %%
help(re)
# Out:
# Help on module re:
#
# NAME
#     re - Support for regular expressions (RE).
#
# DESCRIPTION
#     This module provides regular expression matching operations similar to
#     those found in Perl.  It supports both 8-bit and Unicode strings; both
#     the pattern and the strings being processed can contain null bytes and
#     characters outside the US ASCII range.
#
#     Regular expressions can contain both special and ordinary characters.
#     Most ordinary characters, like "A", "a", or "0", are the simplest
#     regular expressions; they simply match themselves.  You can
#     concatenate ordinary characters, so last matches the string 'last'.
#
#     The special characters are:
#         "."      Matches any character except a newline.
#         "^"      Matches the start of the string.
#         "$"      Matches the end of the string or just before the newline at
#                  the end of the string.
# ...

# %%
re.findall("[Ff]rance",texte)
# Out:
# ['France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
# ...

# %%
chaine = "abcde"

# %%
premiere, suffix = chaine[0], chaine[1:]
print(premiere)
print(suffix)
# Out:
# a
# bcde

# %%
premiere.upper()
# Out:
# 'A'

# %%
premiere.lower()
# Out:
# 'a'

# %%
"[" + premiere.upper() + premiere.lower() + "]" + suffix
# Out:
# '[Aa]bcde'

# %%
# %run occurences_v2.py
# Out:
# 1684

# %%
test = "blaAblabBlaA1B22C333blab2labla"

# %%
motif = re.compile("[A-Z]")
motif.findall(test)
# Out:
# ['A', 'B', 'A', 'B', 'C']

# %%
motif = re.compile("[A-Z][0-9]")
motif.findall(test)
# Out:
# ['A1', 'B2', 'C3']

# %%
motif = re.compile("[A-Z]([0-9])")
motif.findall(test)
# Out:
# ['1', '2', '3']

# %%
motif = re.compile("[A-Z]([0-9]+)")
motif.findall(test)
# Out:
# ['1', '22', '333']

# %%
re.findall("uperficie(.{0,30})", texte)
# Out:
# [' totale</th>',
#  '" title="Liste des pays et ter',
#  '">classé 41<sup>e</sup></a>)</',
#  ' en eau</th>',
#  '"><span class="tocnumber">1.1<',
#  '</span></a></li>',
#  '"></span><span class="mw-headl',
#  '">Localisation, frontières et ',
#  '</span></h3>',
#  '_de_la_France" title="Superfic',
#  ' de la France</a>.</div>',
#  ' de la France métropolitaine à',
#  ' de la France métropolitaine e',
#  ' cadastrale) et à 641&#160;184',
#  ' géodésique). La superficie de',
#  ' forestière en métropole est c',
#  ' totale est de 200&#160;364 km',
#  '" class="mw-redirect" title="S',
#  '">superficie moyenne</a> des e']

# %%
nb_occurences["Allemagne"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-543cd91cb5b2> in <module>()
# ----> 1 nb_occurences["Allemagne"]
#
# NameError: name 'nb_occurences' is not defined

# %%
test= "blaAblabBlaA1B2C3blab2labla"

# %%
motif = re.compile("[A-Z]")
motif.findall(test)
# Out:
# ['A', 'B', 'A', 'B', 'C']

# %%
motif = re.compile("[A-Z]([0-9])")
motif.findall(test)
# Out:
# ['1', '2', '3']

# %%
motif = re.compile("[A-Z]([0-9]+)")
motif.findall(test)
# Out:
# ['1', '22', '333']

# %% [markdown]
# # Exercice

# %% [markdown]
# Trouver les superficies des pays

# %%
re.findall("uperficie(.{0,30})",texte) #le motif juste avant se répète de 0 à 30 fois
# Out:
# [' totale</th>',
#  '" title="Liste des pays et ter',
#  '">classé 41<sup>e</sup></a>)</',
#  ' en eau</th>',
#  '"><span class="tocnumber">1.1<',
#  '</span></a></li>',
#  '"></span><span class="mw-headl',
#  '">Localisation, frontières et ',
#  '</span></h3>',
#  '_de_la_France" title="Superfic',
#  ' de la France</a>.</div>',
#  ' de la France métropolitaine à',
#  ' de la France métropolitaine e',
#  ' cadastrale) et à 641&#160;184',
#  ' géodésique). La superficie de',
#  ' forestière en métropole est c',
#  ' totale est de 200&#160;364 km',
#  '" class="mw-redirect" title="S',
#  '">superficie moyenne</a> des e']

# %% [markdown]
# # Limites

# %%
page_v = rq.get("https://twitter.com/VillaniCedric")

# %%
page_v.status_code
# Out:
# 200

# %%
from pathlib import Path

# %%
chemin = Path("./villani.html")

# %%
chemin.write_text(page_v.text)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-52-95cd02701119> in <module>()
# ----> 1 chemin.write_text(page_v.text)
#
# C:\Python\lib\pathlib.py in write_text(self, data, encoding, errors)
#    1196                             data.__class__.__name__)
#    1197         with self.open(mode='w', encoding=encoding, errors=errors) as f:
# -> 1198             return f.write(data)
#    1199
#    1200     def touch(self, mode=0o666, exist_ok=True):
#
# C:\Python\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# ...

# %%
page = rq.get("https://www.amazon.fr/dp/2412045143")

# %%
page.status_code
# Out:
# 200
